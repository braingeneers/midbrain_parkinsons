# %% [markdown]
# <font size=7>First Glance at Data

# %%
from human_hip import spike_data

# %%
sd = spike_data.read_autocurated_data( "/workspaces/human_hippocampus/data/ephys/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/derived/kilosort2/Hc120523_aav9hckcr1_chip21769_121123_base_acqm.zip" )

# %%
spike_data.text_summary( sd )
# Out:
# Number of spikes:  14742
# Length:  300 seconds
# Number of Neurons:  34
# Average Firing Rate:  1.44
# Coefficient of Variation:  0.525

# %%
spike_data.plot_raster( sd )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (s)', ylabel='Population Firing Rate (Hz)'>)

# %%
spike_data.plot_eigendecomposition_vector( sd )
