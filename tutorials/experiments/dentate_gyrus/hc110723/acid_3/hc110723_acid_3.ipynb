# %% [markdown]
# <font size=7> hc110723

# %%
from human_hip import spike_data

# %%
sd = spike_data.read_autocurated_data("/workspaces/human_hippocampus/data/ephys/2023-11-13-e-Hc110723_hckcr1_21841/derived/kilosort2/Hc110723_hckcr1_21841_111323_4_acqm.zip")

# %%
spike_data.text_summary( sd )
# Out:
# Number of spikes:  15955
# Length:  160 seconds
# Number of Neurons:  57
# Average Firing Rate:  1.75
# Coefficient of Variation:  0.378

# %%
spike_data.plot_raster(sd, smoothness=100)
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
spike_data.plot_raster(sd, xlim=(0,15))
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
spike_data.plot_raster(sd, xlim=(35,40))
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
spike_data.plot_eigendecomposition_vector( sd )
