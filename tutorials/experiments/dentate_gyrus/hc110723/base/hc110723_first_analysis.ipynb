# %% [markdown]
# <font size=7>hc110723

# %%
from human_hip import spike_data

# %%
#sd = spike_data.read_phy_files("/workspaces/human_hippocampus/data/ephys/2023-11-13-e-Hc110723_hckcr1_21841/derived/kilosort2/Hc110723_hckcr1_21841_111323_base_phy.zip")

# %%
sd = spike_data.read_autocurated_data("/workspaces/human_hippocampus/data/ephys/2023-11-13-e-Hc110723_hckcr1_21841/derived/kilosort2/Hc110723_hckcr1_21841_111323_base_acqm.zip")

# %%
spike_data.text_summary( sd )
# Out:
# Number of spikes:  10164
# Length:  308 seconds
# Number of Neurons:  9
# Average Firing Rate:  3.66
# Coefficient of Variation:  0.358

# %%
spike_data.plot_raster(sd)
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
spike_data.plot_eigendecomposition_vector( sd )

# %%
sd = read_phy_files("/workspaces/human_hippocampus/data/ephys/2023-11-13-e-Hc110723_hckcr1_21841/Hc110723_hckcr1_21841_111323_base_curated.zip")

# %%
sd3 = read_phy_files("/workspaces/human_hippocampus/data/ephys/2023-11-13-e-Hc110723_hckcr1_21841/Hc110723_hckcr1_21841_111323_3_curated.zip")

# %%
sd4 = read_phy_files("/workspaces/human_hippocampus/data/ephys/2023-11-13-e-Hc110723_hckcr1_21841/Hc110723_hckcr1_21841_111323_4_curated.zip")

# %%
sd.N
# Out:
# 9

# %%
sd3.N
# Out:
# 123

# %%
sd4.N
# Out:
# 54
