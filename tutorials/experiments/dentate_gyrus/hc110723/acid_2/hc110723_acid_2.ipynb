# %% [markdown]
# <font size=7> hc110723

# %%
from human_hip import spike_data

# %%
sd = spike_data.read_autocurated_data("/workspaces/human_hippocampus/data/ephys/2023-11-13-e-Hc110723_hckcr1_21841/derived/kilosort2/Hc110723_hckcr1_21841_111323_3_acqm.zip")

# %%
spike_data.text_summary( sd )
# Out:
# Number of spikes:  59436
# Length:  200 seconds
# Number of Neurons:  103
# Average Firing Rate:  2.88
# Coefficient of Variation:  0.487

# %%
spike_data.plot_raster(sd)
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
spike_data.plot_eigendecomposition_vector( sd )
