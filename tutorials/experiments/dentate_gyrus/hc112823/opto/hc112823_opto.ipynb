# %% [markdown]
# <font size=7> hc112823 data 1

# %%
from human_hip import spike_data
import numpy as np

# %%
sd = spike_data.read_autocurated_data( "/workspaces/human_hippocampus/data/ephys/2023-12-03-e-Hc112823_avv9hckcr1/derived/kilosort2/Hc112823_avv9hckcr1_21841_120323_1_acqm.zip" )

# %%
opto = np.load('opto_gpio.npy')

# %% [markdown]
# # Raster and Summary Stats

# %%
spike_data.text_summary( sd )
# Out:
# Number of spikes:  286373
# Length:  310 seconds
# Number of Neurons:  228
# Average Firing Rate:  4.05
# Coefficient of Variation:  0.614

# %%
spike_data.plot_raster
# Out:
# <function human_hip.spike_data.plot_raster.plot_raster(sd, title='', opto=[], axs=None, xlim=None, ylim=None, smoothness=20, size=(16, 6))>

# %%
spike_data.plot_raster( sd, opto=opto )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
spike_data.plot_raster( sd, opto=opto,  xlim=(290,310) )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
spike_data.plot_raster( sd, opto=opto, xlim=(298,302) )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)
