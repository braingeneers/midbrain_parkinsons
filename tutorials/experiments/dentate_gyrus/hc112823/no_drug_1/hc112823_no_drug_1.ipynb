# %% [markdown]
# <font size=7> hc112823 data 1

# %% [markdown]
# <font color="red"> TO DO: Make a public version of the dataset and put a command for downloading it into .dev folder

# %%
from human_hip import spike_data

# %%
sd = spike_data.read_autocurated_data( "/workspaces/human_hippocampus/data/ephys/2023-12-03-e-Hc112823_avv9hckcr1/derived/kilosort2/Hc112723_hckcr1_21841_120323_base_acqm.zip" )

# %% [markdown]
# # Raster and Summary Stats

# %%
spike_data.text_summary( sd )
# Out:
# Number of spikes:  338136
# Length:  313 seconds
# Number of Neurons:  249
# Average Firing Rate:  4.34
# Coefficient of Variation:  0.585

# %%
spike_data.plot_raster
# Out:
# <function human_hip.spike_data.plot_raster.plot_raster(sd, title='', axs=None, xlim=None, smoothness=1000, size=(16, 6))>

# %%
spike_data.plot_raster( sd, smoothness=20 )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (s)', ylabel='Population Firing Rate (Hz)'>)

# %%
spike_data.plot_raster( sd, smoothness=20 , xlim=(50000, 100000) )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (s)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# ## Burst 1

# %%
spike_data.plot_raster( sd, smoothness=20 , xlim=(0, 20000) )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (s)', ylabel='Population Firing Rate (Hz)'>)

# %%
spike_data.plot_raster( sd, smoothness=20  , xlim=(7500, 12500) )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (s)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# ## Burst 2

# %%
spike_data.plot_raster( sd, xlim=(200000,220000) )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (s)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# # Plots

# %%
spike_data.plot_summary( sd )

# %% [markdown]
# # STTCs

# %%
spike_data.plot_sttc_hist( sd )
# Out:
# /workspaces/human_hippocampus/src/human_hip/spike_data/plot_matrices_connectivity.py:86: RuntimeWarning: invalid value encountered in log
#   log_array = np.log(flat_array)

# %%
spike_data.plot_sttc_hist( sd, sttc_cutoff_high=0.1 )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 spike_data.plot_sttc_hist( sd, sttc_cutoff_high=0.1 )
#
# File /workspaces/human_hippocampus/src/human_hip/spike_data/plot_matrices_connectivity.py:112, in plot_sttc_hist(sd, bin_count, sttc_cutoff_high, sttc_delta)
#     108 plts["A"].set_title("Original Array")
#     109 plts["A"].legend()
# --> 112 plts["B"].hist(log_array, density=True, bins=bin_count)
#     113 plts["B"].axvline(x=log_mean, color='blue', linewidth=1, label=f'mean = {log_mean:.4f}')
#     114 plts["B"].axvline(x=log_median, color='red', linewidth=1, label=f'Median = {log_median:.4f}')
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
# ...

# %%
spike_data.plot_sttc_matrix( sd, sttc_cutoff_high=.6 )

# %%
spike_data.plot_matrices_connectivity( sd )

# %% [markdown]
# # Functional Connectivity

# %%
spike_data.plot_functional_connectivity_map(sd, sttc_threshold=0.3 )
# Out:
# calculating all latencies...
# making plot

# %% [markdown]
# # Eigenvector Analysis

# %% [markdown]
# <font color="green"> Cuttoff and no-cuttoff give roughly the same results

# %% [markdown]
# ## no cuttoff

# %%
spike_data.plot_eigendecomposition_vector( sd )

# %%
spike_data.plot_eigendecomposition_vector( sd, vector_index=1 )

# %%
spike_data.plot_eigendecomposition_vector( sd, vector_index=2 )

# %% [markdown]
# ## cuttoff 0.3

# %%
spike_data.plot_eigendecomposition_vector( sd, sttc_cutoff_high=0.3, xlim=(100,1700), ylim=(600,1500) )

# %%
spike_data.plot_eigendecomposition_vector( sd, sttc_cutoff_high=0.3 )

# %%
spike_data.plot_eigendecomposition_vector( sd, vector_index=1, sttc_cutoff_high=0.3 )

# %%
spike_data.plot_eigendecomposition_vector( sd, vector_index=2, sttc_cutoff_high=0.3 )

# %%
spike_data.plot_eigendecomposition_vector( sd, vector_index=3, sttc_cutoff_high=0.3 )
