# %% [markdown]
# <font size=7> Data 2 First Look

# %% [markdown]
# <font color="red"> TO DO: Make a public version of the dataset and put a command for downloading it into .dev folder

# %%
import numpy as np
from human_hip import spike_data
from braingeneers.analysis.analysis import SpikeData

# %%
sd = spike_data.read_autocurated_data( "/workspaces/human_hippocampus/data/ephys/2023-12-03-e-Hc112823_avv9hckcr1/derived/kilosort2/Hc112723_hckcr1_21841_120323_base2_acqm.zip" )

# %% [markdown]
# # Data Reference

# %% [markdown]
# **Command to look at datasets:**
#
# aws --endpoint https://s3.braingeneers.gi.ucsc.edu s3 ls s3://braingeneers/ephys/2023-12-03-e-Hc112823_avv9hckcr1/derived/kilosort2/

# %% [markdown]
# **Command to download datasets**
#
#
# aws --endpoint https://s3.braingeneers.gi.ucsc.edu s3 cp s3://braingeneers/ephys/2023-12-03-e-Hc112823_avv9hckcr1/derived/kilosort2/Hc112723_hckcr1_21841_120323_base2_acqm.zip .

# %% [markdown]
# **Local filepath**
#
# /workspaces/human_hippocampus/data/ephys/2023-12-03-e-Hc112823_avv9hckcr1/derived/kilosort2/Hc112723_hckcr1_21841_120323_base2_acqm.zip

# %% [markdown]
# # Raster and Text Summary

# %%
spike_data.text_summary( sd )
# Out:
# Number of spikes:  153743
# Length:  126 seconds
# Number of Neurons:  351
# Average Firing Rate:  3.46
# Coefficient of Variation:  0.61

# %%
spike_data.plot_raster( sd )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
spike_data.plot_raster(sd, smoothness=500, size=(20, 6) )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# # Plots

# %%
spike_data.plot_summary( sd )

# %%
spike_data.plot_sttc_hist( sd )
# Out:
# /workspaces/human_hippocampus/src/human_hip/spike_data/plot_matrices_connectivity.py:86: RuntimeWarning: invalid value encountered in log
#   log_array = np.log(flat_array)

# %%
spike_data.plot_matrices_connectivity( sd )

# %%
spike_data.plot_matrices_connectivity( sd, sttc_cutoff_high=0.3 )

# %%
spike_data.plot_functional_connectivity_map(sd, sttc_threshold=0.2 )
# Out:
# calculating all latencies...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /workspaces/human_hippocampus/tutorials/experiments/dentate_gyrus/hc112823/no_drug_2/hc112823_no_drug_2.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Bzany-orbit-qv76x79p55r2457q/workspaces/human_hippocampus/tutorials/experiments/dentate_gyrus/hc112823/no_drug_2/hc112823_no_drug_2.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> spike_data.plot_functional_connectivity_map(sd, sttc_threshold=0.2 )
#
# File /workspaces/human_hippocampus/src/human_hip/spike_data/plot_functional_connectivity_map.py:95, in plot_functional_connectivity_map(sd, latency_threshold, show_sttc, sttc_threshold)
#      93 # Plot functional connectivity map
#      94 print("calculating all latencies...")
# ---> 95 all_mean_latencies = latencies_mean_all(sd)
# ...

# %% [markdown]
# # Plot eigen layout

# %% [markdown]
# # no cuttoff

# %%
spike_data.plot_eigendecomposition_vector( sd )

# %%
spike_data.plot_eigendecomposition_vector(sd,  vector_index=1 )

# %%
spike_data.plot_eigendecomposition_vector(sd,  vector_index=2 )

# %%
spike_data.plot_eigendecomposition_vector(sd,  vector_index=3 )

# %% [markdown]
# # cuttoff

# %%
spike_data.plot_eigendecomposition_vector(sd, vector_index=0, sttc_cutoff_high=0.3)

# %%
spike_data.plot_eigendecomposition_vector(sd, vector_index=1, sttc_cutoff_high=0.3)

# %%
spike_data.plot_eigendecomposition_vector(sd, vector_index=2, sttc_cutoff_high=0.3)

# %%
spike_data.plot_eigendecomposition_vector(sd, vector_index=3, sttc_cutoff_high=0.3)

# %% [markdown]
# # cuttoff hard

# %%
spike_data.plot_eigendecomposition_vector(sd, vector_index=0, sttc_cutoff_high=0.1)

# %%
spike_data.plot_eigendecomposition_vector(sd, vector_index=1, sttc_cutoff_high=0.2)
