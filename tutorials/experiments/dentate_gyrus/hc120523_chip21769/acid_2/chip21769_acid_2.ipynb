# %% [markdown]
# <font size=7> chip21769 - kanaic acid 2

# %%
from human_hip import spike_data
import numpy as np

# %%
sd = spike_data.read_autocurated_data( "/workspaces/human_hippocampus/data/ephys/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/derived/kilosort2/Hc120523_aav9hckcr1_chip21769_121123_3_acqm.zip" )

# %% [markdown]
# # Raster and Summary Stats

# %%
spike_data.text_summary( sd )
# Out:
# Number of spikes:  49098
# Length:  360 seconds
# Number of Neurons:  52
# Average Firing Rate:  2.62
# Coefficient of Variation:  0.564

# %%
opto = np.load("opto_gpio.npy")

# %%
spike_data.plot_raster
# Out:
# <function human_hip.spike_data.plot_raster.plot_raster(sd, title='', axs=None, xlim=None, smoothness=20, size=(16, 6))>

# %%
spike_data.plot_raster( sd, opto=opto  )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# ## zoom 1

# %%
spike_data.plot_raster( sd, xlim=(80,110), opto=opto )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# ## zoom 2

# %%
spike_data.plot_raster( sd, smoothness=20 , xlim=(250, 280), opto=opto )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# # Plots

# %%
spike_data.plot_summary( sd )

# %% [markdown]
# # STTCs

# %%
spike_data.plot_sttc_hist( sd )
# Out:
# /workspaces/human_hippocampus/src/human_hip/spike_data/plot_matrices_connectivity.py:86: RuntimeWarning: invalid value encountered in log
#   log_array = np.log(flat_array)

# %%
spike_data.plot_sttc_hist( sd, sttc_cutoff_high=0.1 )
# Out:
# /workspaces/human_hippocampus/src/human_hip/spike_data/plot_matrices_connectivity.py:86: RuntimeWarning: divide by zero encountered in log
#   log_array = np.log(flat_array)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /workspaces/human_hippocampus/tutorials/experiments/dentate_gyrus/hc120523_chip21769/acid_2/chip21769_acid_2.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Bzany-orbit-qv76x79p55r2457q/workspaces/human_hippocampus/tutorials/experiments/dentate_gyrus/hc120523_chip21769/acid_2/chip21769_acid_2.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> spike_data.plot_sttc_hist( sd, sttc_cutoff_high=0.1 )
#
# File /workspaces/human_hippocampus/src/human_hip/spike_data/plot_matrices_connectivity.py:112, in plot_sttc_hist(sd, bin_count, sttc_cutoff_high, sttc_delta)
#     108 plts["A"].set_title("Original Array")
#     109 plts["A"].legend()
# ...

# %%
spike_data.plot_sttc_matrix( sd, sttc_cutoff_high=.6 )

# %%
spike_data.plot_matrices_connectivity( sd )

# %% [markdown]
# # Functional Connectivity

# %%
spike_data.plot_functional_connectivity_map(sd, sttc_threshold=0.3 )
# Out:
# calculating all latencies...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 spike_data.plot_functional_connectivity_map(sd, sttc_threshold=0.3 )
#
# File /workspaces/human_hippocampus/src/human_hip/spike_data/plot_functional_connectivity_map.py:95, in plot_functional_connectivity_map(sd, latency_threshold, show_sttc, sttc_threshold)
#      93 # Plot functional connectivity map
#      94 print("calculating all latencies...")
# ---> 95 all_mean_latencies = latencies_mean_all(sd)
#      96 in_out_deg = get_in_out_degree(all_mean_latencies)
#      97 sender_receiver_neurons = label_sender_receiver_neurons(in_out_deg, latency_threshold )
#
# File /workspaces/human_hippocampus/src/human_hip/spike_data/plot_functional_connectivity_map.py:33, in latencies_mean_all(sd)
#      31 latencies_array = [None] * sd.N
#      32 for curr_neuron in range(sd.N):
# ...

# %% [markdown]
# # Eigenvector Analysis

# %% [markdown]
# <font color="green"> Cuttoff and no-cuttoff give roughly the same results

# %% [markdown]
# ## no cuttoff

# %%
spike_data.plot_eigendecomposition_vector( sd )

# %% [markdown]
# ## cuttoff 0.3

# %%
spike_data.plot_eigendecomposition_vector( sd, sttc_cutoff_high=0.3 )
