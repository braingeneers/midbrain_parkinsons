# %% [markdown]
# <font size=7> Latencies Analysis

# %%
import pickle
from human_hip.spike_data import curate_latencies, plot_raster_latency_pairs, plot_vector_layout, read_autocurated_data
from human_hip.animate import animate_latencies

# %%
sd = read_autocurated_data( "/workspaces/human_hippocampus/data/ephys/2023-12-03-e-Hc112823_avv9hckcr1/derived/kilosort2/Hc112723_hckcr1_21841_120323_base2_acqm.zip" )

# %%
good_pairs = curate_latencies(sd)
# Out:
# 123201 Starting Pairs
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 good_pairs = curate_latencies(sd)
#
# File /workspaces/human_hippocampus/src/human_hip/spike_data/latencies.py:101, in curate_latencies(sd, cross_sttc_min_cutoff, cross_sttc_max_cutoff, sttc_cutoff, latency_cutoff, sttc_delta)
#      97 def curate_latencies(sd, cross_sttc_min_cutoff=2, cross_sttc_max_cutoff=15, sttc_cutoff = 0.04, latency_cutoff=1, sttc_delta=20 ):
#      98
#      99     # Get all latencies whose STTC is above some minimum STTC cuttoff
#     100     print(sd.N**2 , "Starting Pairs")
# --> 101     sttc_neo = sd.spike_time_tilings( sttc_delta )    # sttc matrix
#     102     pairs = []                            # get list (without duplicates) of all pairs above cutoff (excluding diagonal)
#     103     for i in range(sd.N):
#
# ...

# %% [markdown]
# <font color="red"> We save curated latency pairs because above calculation took overt 10 minutes.

# %%
# with open( '/workspaces/human_hippocampus/tutorials/experiments/hc112823/no_drug_2/curate_latencies_good_paris.pkl' , 'wb') as my_file:
#    pickle.dump(good_pairs, my_file)

# %%
# load pickled data
with open( '/workspaces/human_hippocampus/tutorials/experiments/hc112823/no_drug_2/curate_latencies_good_paris.pkl' , 'rb') as my_file:
    good_pairs = pickle.load(my_file)

# %%
plot_vector_layout( sd, good_pairs)
#plot_vector_layout( sd, good_pairs, min_dist=250, normalize=True)

# %%
plot_vector_layout( sd, good_pairs, min_dist=500, normalize=True)

# %%
plot_raster_latency_pairs( sd, good_pairs )

# %%
animate_latencies(sd, good_pairs, filename='media/latencies.mp4' )
# Out:
# 6937 latency events occured in total spikedata
# Making animation of 1.058 minutes
# Saved animation to media/latencies.mp4

# %%
# animate_latencies(sd, pairs, movie_range_ms=None, frame_interval_ms=500, directed=True, filename="latencies.mp4",
#                       latency_ms_cutoff_low=0, latency_ms_cutoff_high=15 ):

# %%
animate_latencies
# Out:
# <function human_hip.animate.animate_latency_pairs.animate_latencies(sd, pairs, movie_range_ms=None, frame_interval_ms=500, directed=True, directed_backwards=False, filename='latencies.mp4', latency_ms_cutoff_low=1, latency_ms_cutoff_high=15, plot_vector=False, min_dist=0)>

# %%
animate_latencies(sd, good_pairs, filename='media/latencies_mindist500.mp4', min_dist=500 )
# Out:
# 6937 latency events occured in total spikedata
# 1603 latency events occured above 500 um distance
# Making animation of 1.058 minutes
# Saved animation to media/latencies_mindist500.mp4
