# %% [markdown]
# <font size=7> Data 1- Raw Animations

# %%
import pickle
from human_hip.raw_data import get_brain_waves
from human_hip.animate import animate_waves

# %% [markdown]
# # 105 Seconds

# %%
with open("/workspaces/human_hippocampus/data/ephys_raw/2023-12-03-e-Hc112823_avv9hckcr1/base_start105s_stop115s_fs1ms.pkl", 'rb') as filename:
    data_raw = pickle.load(filename)
data_raw.keys()
# Out:
# dict_keys(['data', 'xy', 'frame_rate'])

# %% [markdown]
# ## Theta

# %%
#print(waves["alpha"].shape)
waves = get_brain_waves(data_raw["data"], data_raw["frame_rate"])
for i in range(0,300,100):
    #print(i)
    plt.figure(figsize=(20,3))
    plt.plot( [*range(waves["basic"].shape[1])], waves["theta"][i,:] )
    plt.show()

# %%
#animate_waves_theta( data_raw, movie_range_ms= range(0,1000, 5) )

# %% [markdown]
# ## Alpha

# %%
waves = get_brain_waves(data_raw["data"], data_raw["frame_rate"])["alpha"]
waves.shape
# Out:
# (887, 10000)

# %%
#print(waves["alpha"].shape)
waves = get_brain_waves(data_raw["data"], data_raw["frame_rate"])["alpha"]
for i in range(0,300,100):
    #print(i)
    plt.figure(figsize=(20,3))
    plt.plot( [*range(waves.shape[1])], waves[i,:] )
    plt.show()

# %%
animate_waves_alpha( data_raw )
# Out:
# Making animation of 5.557 minutes
# Saved animation to alpha_waves.mp4

# %% [markdown]
# ## Delta

# %%
animate_waves(data_raw, "delta")
# Out:
# Making animation of 1.283 minutes
# Saved animation to waves.mp4

# %% [markdown]
# ## Beta

# %%
animate_waves(data_raw, "beta")

# %% [markdown]
# # 5 Seconds

# %%
with open("/workspaces/human_hippocampus/data/ephys_raw/2023-12-03-e-Hc112823_avv9hckcr1/base_start5s_stop15s_fs1ms.pkl", 'rb') as filename:
    data_raw = pickle.load(filename)
data_raw.keys()
# Out:
# dict_keys(['data', 'xy', 'frame_rate'])

# %% [markdown]
# ## Theta

# %%
animate_waves(data_raw, "theta", filename="media/5s_theta.mp4")
# Out:
# Making animation of 3.333 minutes

# %% [markdown]
# ## Alpha

# %%
animate_waves(data_raw, "alpha", filename="media/5s_alpha.mp4")
# Out:
# Making animation of 5.557 minutes
# Saved animation to media/5s_alpha.mp4

# %% [markdown]
# ## Delta

# %%
animate_waves(data_raw, "delta", filename="media/5s_delta.mp4")
# Out:
# Making animation of 1.283 minutes
# Saved animation to media/5s_delta.mp4

# %% [markdown]
# ## Beta

# %%
animate_waves(data_raw, "beta", filename="media/5s_beta.mp4")
# Out:
# Making animation of 3.333 minutes
# Saved animation to media/5s_beta.mp4
