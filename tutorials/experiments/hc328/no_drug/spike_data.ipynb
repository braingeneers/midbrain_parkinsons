# %% [markdown]
# <font size=7>HC-3.28 Spike Data Analysis

# %% [markdown]
# # Setup

# %% [markdown]
# import packages

# %%
import pickle

from human_hip import spike_data

# %% [markdown]
# load data

# %%
with open('/workspaces/human_hippocampus/data/ephys/2023-04-02-e-hc328_unperturbed/sd_ca1_curated.pkl', 'rb') as my_file:
    sd = pickle.load(my_file)

# %% [markdown]
# # Simple Summary

# %% [markdown]
# Below are some basic summary statistics about the data:

# %%
spike_data.text_summary( sd )
# Out:
# Number of spikes:  95706
# Length:  385 seconds
# Number of Neurons:  136
# Average Firing Rate:  1.83
# Coefficient of Variation:  0.543

# %% [markdown]
# and some plots:

# %%
spike_data.plot_summary( sd )

# %% [markdown]
# and more plots:

# %%
spike_data.plot_matrices_connectivty( sd )
