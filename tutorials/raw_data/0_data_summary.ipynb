# %% [markdown]
# <font size=7> Raw Files Summary

# %% [markdown]
# This notebook summarize the raw datasets that are used for analysis. These datasets are located in the folder `ephys/data_raw`. We analyze raw data from every human slice we ran an experiment on. Below is a summary of the files relating to each slice. If you want a more general summary of the datasets, cehck out the tutorial, `data_reference/1_data_summary.ipynb`.

# %%
from human_hip.spike_data import read_phy_files, raster_fancy_plot

# %% [markdown]
# # Adult Dentate Gyrus

# %% [markdown]
# The experiment has both a recording without any drugs and a recording with bicculine added. Below are all the raw files.

# %% [markdown]
# **No Drug**
# * 2022-11-02-e-Hc11.1-chip16753/immediate_start34s_stop44s_fs1ms.pkl
# * 2022-11-02-e-Hc11.1-chip16753/immediate_start325s_stop335s_fs1ms.pkl
#
# **Bicuculline**
# * 2022-11-02-e-Hc11.1-chip16753/D_start5s_stop15s_fs1ms.pkl

# %% [markdown]
# The <font color="magenta"> No Drug </font> data contains two datasets <font color="magenta">34-44</font> seconds and <font color="magenta">325-335</font> seconds. <font color="magenta">34-44</font> is just standard level activity.  <font color="magenta">325-335</font> is a paticularly large peak, but I don't know if this is a burst or an artifact.
# The <font color="green"> Bicuculline </font> data contains 3 datasets <font color="green">5-15</font> and <font color="green">210-220</font> seconds. <font color="green">5-15</font> is probably less good, because although is shows strong activity, it's befre the bicuculline dramaticallyu increases activity. The  <font color="green">210-220</font> is more active and  a better representation of what bicuclline does.

# %% [markdown]
# ## <font color="magenta"> No Drug

# %% [markdown]
# We inspect the recording by looking at the spike data.

# %%
sd = read_phy_files("/workspaces/human_hippocampus/data/ephys/2022-11-02-e-Hc11.1-chip16753/derived/kilosort2/hc11.1_plated-11.1_chip-16753_rec_11.2.22AM-immediate_curated.zip")

# %%
raster_fancy_plot(sd, xsize=15, ysize=4)

# %% [markdown]
# The **34-44** second recording:

# %%
raster_fancy_plot(sd, xsize=15, ysize=4, start_time=34, stop_time=44 )

# %% [markdown]
# The **325-335** recording

# %%
raster_fancy_plot(sd, xsize=15, ysize=4, start_time=325, stop_time=335 )

# %% [markdown]
# ## <font color="green">Bicuculline

# %% [markdown]
# **Note-** The dataset from which the raw data comes from has yet to be curated, so I am unable to view the raster. The dataset that needs to be curated is: `hc11.1_plated-11.1_chip-16753_rec_11.2.22AM-immediate_D_phy.zip`

# %% [markdown]
# To get a general idea about the data, I view the raster on the UCSF computer using the maxwell software. Then chose time pieces that looked acceptable. To find the recording search for the folder  `Home/Data/recordings/hc11.1_chip16753_ppd0_11.2.22`

# %% [markdown]
# # ?Anterior? CA1

# %% [markdown]
# There are **3 recordings** of this slice. The slices come tissue without any drug added. They are listed below:
#
# * 2023-04-02-e-hc328_unperturbed/raw_start120s_stop130s_fs1ms.pkl
# * 2023-04-02-e-hc328_unperturbed/raw_start190s_stop200s_fs1ms.pkl
# * 2023-04-02-e-hc328_unperturbed/raw_start350s_stop365s_fs1ms.pkl

# %% [markdown]
# We now take a look at the spike data this particular recording. We focus in on the regions regions that we extracted raw data from.

# %%
sd = read_phy_files('/workspaces/human_hippocampus/data/ephys/2023-04-02-e-hc328_unperturbed/derived/kilosort2/hc3.28_hckcr1_chip16835_plated34.2_rec4.2_curated.zip')

# %%
raster_fancy_plot(sd, xsize=25, ysize=5)

# %% [markdown]
# **120-130**

# %%
raster_fancy_plot(sd, xsize=25, ysize=5, start_time=110, stop_time=140)

# %% [markdown]
# **190-200**

# %%
raster_fancy_plot(sd, xsize=25, ysize=5, start_time=180, stop_time=210)

# %% [markdown]
# **350-365**

# %%
raster_fancy_plot(sd, xsize=25, ysize=5, start_time=340, stop_time=375)

# %% [markdown]
# # ?Posterior? CA1 Region

# %% [markdown]
# The experiment has both a recording with any drugs and a recording with bicculine. There analyze both of these two different files.

# %% [markdown]
# ## No Drug

# %% [markdown]
# ## Bicuculline
