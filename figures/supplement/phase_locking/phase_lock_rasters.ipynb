# %% [markdown]
# <font size=7> Phase Lock Rasters

# %% [markdown]
# # <font color="grey"> Setup

# %%
from human_hip import spike_data
import numpy as np
from human_hip.spike_data import *
import pickle

# %% [markdown]
# # <font color="red">HC112823 - ACID

# %% [markdown]
# **seizure**

# %%
sd = spike_data.read_autocurated_data( "/workspaces/human_hippocampus/data/ephys/2023-12-03-e-Hc112823_avv9hckcr1/derived/kilosort2/Hc112823_avv9hckcr1_21841_120323_3_acqm.zip" )

# %%
seizure= np.array( [[9,28],[38,52],[69,83],[100,113],[138,151],[176,187],[211,220],[246,254] ] )
spike_data.plot_raster( sd, opto=seizure )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# **non-seizure**

# %%
nonseizure = [ [28,38], [54,66], [85,97], [115,127], [155,167], [193,205], [228,240], [260,272] ]
spike_data.plot_raster( sd, opto=nonseizure )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
#spike_data.plot_raster( sd, opto=raw_recordings, xlim=(0,60) ) #, opto=opto )

# spike_data.plot_raster( sd, opto=raw_recordings, xlim=(95,120) )

# plt.vlines( 100, 0, 20, color='r' )
# plt.vlines( 113, 0, 20, color='r' )

# %% [markdown]
# # <font color="red">HC112823 - baseline

# %%
with open("/workspaces/human_hippocampus/data/ephys/2023-12-03-e-Hc112823_avv9hckcr1/curated_base_acqm.pkl", "rb") as filename: sd = pickle.load(filename)

# %%
baseline = [ [25,35], [60,70], [105,115], [150,160], [250,260] ]
spike_data.plot_raster( sd, opto=baseline )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# # <font color="red">Chip 21769 - Acid

# %% [markdown]
# **seizure**

# %%
sd = spike_data.read_phy_files("/workspaces/human_hippocampus/data/ephys/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/elliott/elliott_chip21769_2.zip")

# %%
seizure = np.array([ [0,11],[25,39],[139,148],[168,174], [258,263], [320,328],[481,487] ])

print( np.sum( seizure[:,1] - seizure[:,0] ), "total seconds")
# Out:
# 59 total seconds

# %%
spike_data.plot_raster( sd, opto=seizure )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# **nonseizure**

# %%
nonseizure = np.array([ [50,60] ,[100,113], [200, 212], [270,275], [392, 400],  [400,406], [450,455] ])

print( np.sum( nonseizure[:,1] - nonseizure[:,0] ), "total seconds")
# Out:
# 59 total seconds

# %%
spike_data.plot_raster( sd, opto=nonseizure )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# # <font color="red">Chip 21769 - baseline

# %%
sd = read_phy_files("/workspaces/human_hippocampus/data/ephys/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/elliott/elliott_chip21769_base.zip")

# %%
baseline = [ [60,70], [100,110], [150,160], [200,210], [250,260] ]
spike_data.plot_raster( sd, opto=baseline )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# # HC328

# %%
with open("/workspaces/human_hippocampus/data/ephys/2023-04-02-e-hc328_unperturbed/sd_ca1_curated.pkl", "rb") as filename:
    sd = pickle.load(filename)
raw_recordings= np.array([ [120,130],[190,200],[350,365] ])

# %%
spike_data.plot_raster( sd, opto=raw_recordings )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
spike_data.plot_raster( sd, opto=raw_recordings, xlim=(100,200) )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# # HC52

# %%
with open('/workspaces/human_hippocampus/data/ephys/2023-05-10-e-hc52_18790_unperturbed/5-10-23s1-CutData.pkl', 'rb' ) as my_file:
    sd = pickle.load(my_file)
raw_recordings= np.array([ [6,16],[19,29],[50,60] ])

# %%
spike_data.plot_raster( sd, opto=raw_recordings )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
spike_data.plot_raster( sd, opto=raw_recordings, xlim=(0,30) )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# # HC110723

# %%
# with open("/workspaces/human_hippocampus/data/ephys/2023-11-13-e-Hc110723_hckcr1_21841/hc110723_sd.pkl", "rb") as f:
#     sd = pickle.load(f)

# %%
sd = read_phy_files("/workspaces/human_hippocampus/data/ephys/2023-11-13-e-Hc110723_hckcr1_21841/elliott/hc110723_2.zip")
raw_recordings= np.array([ [33,43], [110,120], [145,155] ])

# %%
plot_raster(sd, opto=raw_recordings)
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# # HC111

# %%
sd = read_phy_files( "/workspaces/human_hippocampus/data/ephys/2022-11-02-e-Hc11.1-chip16753/derived/kilosort2/hc11.1_plated-11.1_chip-16753_rec_11.2.22AM-immediate_curated.zip" )
raw_recordings= np.array([ [34,44], [200,210] , [325,335] ])

# %%
plot_raster(sd, opto=raw_recordings)
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)
