# %% [markdown]
# <font size=7> HC111 - raw data

# %%
import pickle
from matplotlib import pyplot as plt
from human_hip.raw_data import get_brain_waves, cwt_spectrogram, spectrogram_plot
from human_hip.spike_data import read_autocurated_data, plot_raster, read_phy_files

import braingeneers.data.datasets_electrophysiology as ephys
from human_hip.spike_data import read_phy_files, read_autocurated_data,  plot_raster
from human_hip import raw_data
import pickle

# %%
sd = read_phy_files( "/workspaces/human_hippocampus/data/ephys/2022-11-02-e-Hc11.1-chip16753/derived/kilosort2/hc11.1_plated-11.1_chip-16753_rec_11.2.22AM-immediate_curated.zip" )

# %%
plot_raster( sd )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
raw_data.data_get_experiments("2022-11-02-e-Hc11.1-chip16753")
# Out:
# experiment3  -  original/data/hc11.1_plated-11.1_chip-16753_rec_11.2.22AM-immediate.raw.h5
# experiment1  -  original/data/hc11.1_plated-11.1_chip-16753_rec_11.2.22AM-immediate_stim.raw.h5
# experiment5  -  original/data/hc11.1_plated-11.1_chip-16753_rec_11.2.22AM-immediate_stim-B.raw.h5
# experiment4  -  original/data/hc11.1_plated-11.1_chip-16753_rec_11.2.22AM-immediate_stim-C.raw.h5
# experiment2  -  original/data/hc11.1_plated-11.1_chip-16753_rec_11.2.22AM-immediate_D.raw.h5
# experiment6  -  original/data/hc11.1_plated-11.1_chip-16753_rec_11.2.22AM-immediate_E.raw.h5

# %%
raw_data.data_create("2022-11-02-e-Hc11.1-chip16753", "experiment3", start_s=200, length_s=10,
                      save_path="/workspaces/human_hippocampus/data/ephys_raw/2022-11-02-e-Hc11.1-chip16753/immediate_start200s_stop210s_fs1ms.pkl" )
# Out:
# Loading Data... might take up to 10min
# /srv/conda/envs/notebook/lib/python3.10/site-packages/braingeneers/data/datasets_electrophysiology.py:203: UserWarning: Dataset 2022-11-02-e-Hc11.1-chip16753 is not in row-major format, the parallel data reader can't be used, read speeds may be slow over a network.
#   warnings.warn(f'Dataset {batch_uuid} is not in row-major format, the parallel data reader '
# /srv/conda/envs/notebook/lib/python3.10/site-packages/braingeneers/data/datasets_electrophysiology.py:215: UserWarning: Metadata is missing the required voltage_scaling_factor attribute. Using default value of 1.0.
#   warnings.warn('Metadata is missing the required voltage_scaling_factor attribute. Using default value of 1.0.')
# Saving Data...
# Done!
