# %% [markdown]
# <font size=7> Spectrograms

# %% [markdown]
# The rest of the figures for this supplement are in `Figure2/spectrogram`

# %%
from human_hip import spike_data
import numpy as np

# %%
sd = spike_data.read_autocurated_data( "/workspaces/human_hippocampus/data/ephys/2023-12-03-e-Hc112823_avv9hckcr1/derived/kilosort2/Hc112823_avv9hckcr1_21841_120323_3_acqm.zip" )

# %% [markdown]
# # Seizure Slice 1

# %%
spike_data.plot_raster( sd,  xlim=(9, 29),  size=(22,6), title="Neural Population Firing Rate" )
# Out:
# (<Axes: title={'center': 'Neural Population Firing Rate'}, xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# # Seizure Slice 2
