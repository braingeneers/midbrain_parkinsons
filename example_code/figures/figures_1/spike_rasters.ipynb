# %% [markdown]
# <font size=7> HC1128 Spike Rasters

# %%
from human_hip import spike_data
import numpy as np

# %%
sd = spike_data.read_autocurated_data( "/workspaces/human_hippocampus/data/ephys/2023-12-03-e-Hc112823_avv9hckcr1/derived/kilosort2/Hc112823_avv9hckcr1_21841_120323_3_acqm.zip" )

# %%
#opto = np.load("opto_gpio.npy")

# %%
spike_data.text_summary( sd )
# Out:
# Number of spikes:  320923
# Length:  360 seconds
# Number of Neurons:  212
# Average Firing Rate:  4.2
# Coefficient of Variation:  0.645

# %%
spike_data.plot_raster
# Out:
# <function human_hip.spike_data.plot_raster.plot_raster(sd, title='', opto=[], axs=None, xlim=None, ylim=None, smoothness=20, size=(16, 6))>

# %%
spike_data.plot_raster( sd, smoothness=20 , xlim=(3, 155), size=(13, 7))
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
spike_data.plot_raster( sd, smoothness=20 , xlim=(12, 24), size=(10, 7), ylim=(0,14))
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)
