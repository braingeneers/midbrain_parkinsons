# %% [markdown]
# <font size="7">Local Field Potentials

# %% [markdown]
# #  <font color="grey">Set Up Notebook

# %%
import matplotlib.pyplot as plt         # packages for plotting
from matplotlib.colors import Normalize
from IPython.display import display

import numpy as np         # common packages for analysis andl loading data
from scipy import signal 
from scipy.signal import correlate, correlation_lags
import pickle 

from human_hip.spike_data import read_phy_files,  plot_raster, read_autocurated_data
from human_hip.raw_data import  get_brain_waves, spectrogram_plot, cwt_spectrogram, butter_filter

# %%
fs = 20000/20 # frame rate-- we downsampled a 20000 frames per second recording by 40
print(f"data has {fs} frames per second")
# Out:
# data has 1000.0 frames per second

# %%
file = open("/workspaces/human_hippocampus/data/ephys_raw/2023-12-03-e-Hc112823_avv9hckcr1/acid1_start38s_stop52s_fs1ms.pkl", 'rb')
data_dict = pickle.load(file)
file.close()

# %%
print( data_dict.keys() )
data = data_dict['data']
# Out:
# dict_keys(['data', 'xy', 'frame_rate', 'uuid', 'file'])

# %%
sd = read_autocurated_data( "/workspaces/human_hippocampus/data/ephys/2023-12-03-e-Hc112823_avv9hckcr1/derived/kilosort2/Hc112823_avv9hckcr1_21841_120323_3_acqm.zip" )
sd.N
# Out:
# 212

# %% [markdown]
# # Get Neuron channels

# %% [markdown]
# <font color="orange"> Chosesn neurons from `latency_histogram.ipynb` - 147,90

# %%
print("neuron", "147")
print( "channel", sd.neuron_data[0][147]["channel"]  )
print("position", sd.neuron_data[0][147]["position"] )
# Out:
# neuron 147
# channel 183
# position [1470.  1347.5]
# /tmp/ipykernel_1042/2546404990.py:2: DeprecationWarning: Call to deprecated function (or staticmethod) neuron_data. (Use NeuronAttributes instead of neuron_data, with the function load_spike_data())
#   print( "channel", sd.neuron_data[0][147]["channel"]  )
# /tmp/ipykernel_1042/2546404990.py:3: DeprecationWarning: Call to deprecated function (or staticmethod) neuron_data. (Use NeuronAttributes instead of neuron_data, with the function load_spike_data())
#   print("position", sd.neuron_data[0][147]["position"] )

# %%
print("neuron", "90")
print( "channel", sd.neuron_data[0][90]["channel"]  )
print("position", sd.neuron_data[0][90]["position"] )
# Out:
# neuron 90
# channel 738
# position [ 945.  1347.5]
# /tmp/ipykernel_1042/2172254797.py:2: DeprecationWarning: Call to deprecated function (or staticmethod) neuron_data. (Use NeuronAttributes instead of neuron_data, with the function load_spike_data())
#   print( "channel", sd.neuron_data[0][90]["channel"]  )
# /tmp/ipykernel_1042/2172254797.py:3: DeprecationWarning: Call to deprecated function (or staticmethod) neuron_data. (Use NeuronAttributes instead of neuron_data, with the function load_spike_data())
#   print("position", sd.neuron_data[0][90]["position"] )

# %% [markdown]
# ## <font color="brown"> Try 1

# %%
sd.neuron_data[0][90]
# Out:
# /tmp/ipykernel_1042/2138754453.py:1: DeprecationWarning: Call to deprecated function (or staticmethod) neuron_data. (Use NeuronAttributes instead of neuron_data, with the function load_spike_data())
#   sd.neuron_data[0][90]
# {'cluster_id': 199,
#  'channel': '738',
#  'position': array([ 945. , 1347.5]),
#  'template': array([-4.9046323e-02, -2.9972753e-02,  0.0000000e+00,  6.5395094e-02,
#          1.4168938e-01,  2.1798365e-01,  2.5885558e-01,  3.4332424e-01,
#          3.7874660e-01,  3.5422343e-01,  3.5422343e-01,  3.7057221e-01,
#          4.2234331e-01,  4.7138965e-01,  5.1226157e-01,  6.2125343e-01,
#          6.6212535e-01,  6.5122616e-01,  6.1035424e-01,  6.3215262e-01,
#          6.4577657e-01,  6.8119889e-01,  7.4114442e-01,  7.7111715e-01,
#          8.4741145e-01,  8.3651227e-01,  8.8283378e-01,  8.3378744e-01,
#          7.7384198e-01,  7.2207087e-01,  6.1852860e-01,  3.7329701e-01,
#          2.8882834e-01,  1.3351499e-01, -2.8882834e-01, -5.5313349e-01,
#         -8.0926430e-01, -2.0190735e+00, -5.0626702e+00, -7.8228884e+00,
#         -7.7520437e+00, -5.5803814e+00, -3.4087193e+00, -1.8855586e+00,
#         -7.3297000e-01,  1.1716621e-01,  5.9945506e-01,  8.4196186e-01,
#          1.0354223e+00,  1.2479564e+00,  1.5476840e+00,  1.8147140e+00,
#          1.9673024e+00,  2.0490463e+00,  2.0735695e+00,  2.1089919e+00,
#          2.0435967e+00,  1.8801090e+00,  1.6757493e+00,  1.4850136e+00,
#          1.2806540e+00,  1.1280653e+00,  9.6730244e-01,  7.1934605e-01,
#          5.0408721e-01,  2.3705722e-01,  1.1989101e-01, -2.9972753e-02,
#         -1.5531336e-01, -2.1798365e-01, -2.6702997e-01, -2.4795641e-01,
#         -2.6158038e-01, -2.5068119e-01, -3.6239782e-01, -5.1226157e-01,
#         -6.3215262e-01, -6.5940052e-01, -6.3760215e-01, -6.1580384e-01,
#         -5.6130791e-01, -5.0408721e-01, -5.3405994e-01, -5.1771116e-01,
#         -4.6594006e-01, -4.1144413e-01, -3.3787465e-01, -2.4523161e-01,
#         -1.2806539e-01, -9.2643052e-02, -8.1743866e-02, -2.4523161e-02,
#         -4.3596730e-02, -2.7247956e-02, -2.9972753e-02, -2.7247956e-03,
#         -4.6321526e-02, -8.7193459e-02, -7.9019077e-02, -5.4495912e-02],
#        dtype=float32),
#  'neighbor_channels': array(['738', '809', '545', '793', '722', '754', '750', '726', '710',
#         '949', '734', '21'], dtype='<U64'),
#  'neighbor_positions': array([[ 945. , 1347.5],
#         [ 945. , 1382.5],
#         [ 910. , 1347.5],
#         [ 945. , 1312.5],
#         [ 980. , 1382.5],
#         [ 910. , 1312.5],
#         [ 910. , 1382.5],
#         [ 980. , 1312.5],
#         [1015. , 1347.5],
#         [1015. , 1382.5],
#         [ 945. , 1417.5],
#         [1015. , 1312.5]]),
#  'neighbor_templates': array([[-0.04904632, -0.02997275,  0.        , ..., -0.08719346,
#          -0.07901908, -0.05449591],
#         [-0.10081744, -0.09264305, -0.04904632, ..., -0.10354223,
#          -0.14713897, -0.13079019],
#         [-0.11989101, -0.04087193,  0.03814714, ..., -0.05722071,
#          -0.10354223, -0.05994551],
#         ...,
#         [ 0.04632153,  0.00544959, -0.00817439, ..., -0.14168938,
#          -0.13351499, -0.0626703 ],
#         [-0.08174387, -0.08719346, -0.04904632, ..., -0.02179836,
#          -0.06811989, -0.07084469],
#         [ 0.01362398,  0.05449591,  0.11444142, ..., -0.05994551,
#          -0.07356948, -0.00817439]], dtype=float32)}

# %%
['neighbor_positions']

# %%
data_raw = data_dict
electrode_mapping = data_raw["xy"].copy()
electrode_mapping[:,1] = data_raw["xy"][:,0]/12.5
electrode_mapping[:,0] = data_raw["xy"][:,1]

# %%
# Add background image
plt.figure(figsize=(15,10))       # Set image size to roughly the shape of the MEA
img = plt.imread("/workspaces/human_hippocampus/data/histology/hc112823_bw.png")      # Load in image
plt.imshow(img,  extent=[0, 3850, 0, 2100]) # Plot image, have it correspond to electrode dimensions
plt.scatter( electrode_mapping[:,0], electrode_mapping[:,1], s=7, c="red", alpha=.4) # Plot electrodes

# Add selected electrodes
plt.scatter( electrode_mapping[183,0], electrode_mapping[183,1], s=300, edgecolors='white',c="darkviolet" )
plt.scatter( electrode_mapping[738,0], electrode_mapping[738,1], s=300, edgecolors='white', c="#ff9408")


# #add legend, axises limits, labels,  and title
# #legend_elements = [Patch(facecolor=electrode_color) ]   # Create colors in legend
# #plt.legend(legend_elements, ["Electrode"])       # Add legend       
# plt.legend()
plt.xlim(0,1750)                                      # Set axis limits to that of the MEA
plt.ylim(0, 1750)
plt.xlabel('um')                                         # add axises and title
plt.ylabel('um')
plt.title(f"Neuron & Electrode Layout")
# #plt.show()
# Out:
# Text(0.5, 1.0, 'Neuron & Electrode Layout')

# %% [markdown]
# # Get Raw waves

# %% [markdown]
# * Start time in ms: `44585`
# * End time in ms: `44635`
# * Raw Data start ms: `38000`

# %%
start_ms = 44585-38000
stop_ms = 44635 - 38000

raw1 = data[183,start_ms:stop_ms]
raw2 = data[738,start_ms:stop_ms]
raw1.shape
# Out:
# (50,)

# %%
plt.plot( [*range(len(raw1))], raw1 )

# %%
plt.plot( [*range(len(raw2))], raw2 )

# %%
waves = get_brain_waves( data_raw["data"],fs=data_raw["frame_rate"])
waves.keys()
# Out:
# dict_keys(['original', 'basic', 'low', 'delta', 'theta', 'alpha', 'beta', 'gamma'])

# %%
basic1 = waves["original"][182,start_ms:stop_ms]
basic2 = waves["original"][738,start_ms:stop_ms]

# %%
plt.plot( [*range(len(basic1))], basic1 )

plt.vlines([1.85,27.6,36.45], 500, 510, color='red', alpha=0.7)

# %%
plt.plot( [*range(len(basic2))], basic2 )

plt.vlines([5.35,24.25,45.2], 485, 500, color='red', alpha=0.7)

# %% [markdown]
# # <font color="fuchsia">Single Channel Analysis

# %% [markdown]
# Look at raw data from a single channel

# %%
data1 = data[1,:]

# %% [markdown]
# ## <font color="fuchsia"> Bandpass filtering

# %%
plt.plot( [*range(len(data1))], data1 )

# %%
waves = get_brain_waves( data1,fs=fs)

# %%
plt.plot( [*range(len(data1))], waves["basic"] )

# %%
print("Data before filtering")
display(data1)
print("Data after")
display(waves["basic"])
# Out:
# Data before filtering
# array([515.56836, 519.23175, 517.4527 , ..., 522.0156 , 521.5279 ,
#        521.4618 ], dtype=float32)
# Data after
# array([-0.68763337,  0.06636413,  0.6888468 , ...,  3.26201911,
#         3.21252634,  3.09869049])

# %% [markdown]
# ## <font color="fuchsia"> Plot Bands

# %% [markdown]
# Neuroscientists like to filter the lfp according into specific bands for analysis. Lets do that!

# %%
for key,val in waves.items():
    plt.figure(figsize=(20,4))
    plt.plot( [*range(len(val))], val )
    plt.title(key)
    plt.show()

# %% [markdown]
# Check that adding up filters creates original plot

# %%
wav_reconstructed = np.zeros(len(waves["basic"]))
for wave_name in [ "low", "delta", "theta", "alpha", "beta", "gamma"]:
    wav_reconstructed = wav_reconstructed + waves[wave_name]

# %%
plt.figure(figsize=(20,4))
plt.plot( np.array([*range(len(wav_reconstructed))])/fs, wav_reconstructed )
plt.xlabel('time (s)')
# Scale to same ylim
plt.title("Reconstructed LFP")
plt.show()

# %% [markdown]
# ## <font color="fuchsia"> Spectrogram... FFT? - <font color="gray"> Check with Sury

# %%
# get teh spectrum for a single electrode
power, times, frequencies, coif = cwt_spectrogram( waves["basic"][0,:], fs, nNotes=12)

# %%
#print(i, channel,raw_trace.shape)
fig, axs = plt.subplots(1, 1, figsize=(20, 6))
spectrogram_plot(power, times, frequencies, coif, ax=axs)

axs.set_title(f"spectrum", fontsize=12)
#axs.set_xlim(0, len(data1_lfp)/fs ) # code causes errors
#axs.set_ylim(0, 100)
axs.set_xlabel('time (s)')
axs.set_ylabel('frequency (Hz)')
axs.set_yscale('log')
plt.show(block=False)

# %% [markdown]
# # <font color="peru"> Multi-channel Analysis

# %%
data_delta = butter_filter( data, 0.5, 4, fs=fs)

# %%
data_delta[1,:]
# Out:
# array([-2.77847025, -2.70476396, -2.62754986, ...,  0.02379423,
#         0.02049006,  0.01754955])

# %%
plt.figure(figsize=(20,4))
plt.plot( [*range(len(data_delta[1,:]))], data_delta[1,:] )
plt.title(key)
plt.show()

# %% [markdown]
# ## <font color="peru">Neuron Layouts

# %% [markdown]
# From the raw data we spike sorted the data to find the location of active neurons. Below is a spike raster of the neurons for hte first 20 seconds

# %%
raster_fancy_plot(sd, xsize=25, ysize=5, start_time=0, stop_time=20)

# %% [markdown]
# <font color="red">
#
# **To Do-** Notice that there's higher activity than usual around second 4. Compare the LFP's from neurons at second 4 to see if there is a pattern.

# %% [markdown]
# Here is view of the neurons in 2D space.

# %%
# Get the X/Y locations of neurons in 2D space
neuron_xy = []
for neuron in sd.neuron_data[0].values():
    neuron_xy.append( [neuron['position'][0], neuron['position'][1]] )
neuron_xy = np.array(neuron_xy)

# Plot the locations
plt.figure(figsize=(8, 8))
plt.scatter( neuron_xy[:,0], neuron_xy[:,1], alpha=0.15, c='grey')
# Out:
# /tmp/ipykernel_2005/226950929.py:3: DeprecationWarning: Call to deprecated function (or staticmethod) neuron_data. (Use NeuronAttributes instead of neuron_data, with the function load_spike_data())
#   for neuron in sd.neuron_data[0].values():

# %% [markdown]
# We can also view which channel corresponds to each neurons

# %%
neuron_channels = []
for neuron in sd.neuron_data[0].values():
    neuron_channels.append( neuron['channel'] )
neuron_channels = np.array(neuron_channels)
# Out:
# /tmp/ipykernel_2005/2787768017.py:2: DeprecationWarning: Call to deprecated function (or staticmethod) neuron_data. (Use NeuronAttributes instead of neuron_data, with the function load_spike_data())
#   for neuron in sd.neuron_data[0].values():

# %%
neuron_channels
# Out:
# array([  0, 843, 155, 165, 119,  36, 240,  56, 905,  70, 175,  76,  84,
#         96, 104, 704, 807, 398, 112, 953, 127, 140, 143, 154, 157, 174,
#        175, 176, 219, 199, 187, 207, 212, 220,  28, 228,  36, 844, 844,
#        242, 205, 245, 249,   3, 268, 224, 282, 720,  55, 714, 302, 337,
#        293, 339, 400, 717, 945, 448, 491, 489, 490, 490, 501, 520, 532,
#        560, 560, 564, 172, 174, 598, 795, 888, 629, 630, 652, 640, 238,
#        667, 667, 679, 177, 686, 686, 692, 714, 735, 741, 756, 761, 762,
#        774, 797, 273, 796, 415, 151, 816, 862, 681, 833, 836, 857, 862,
#        865, 886, 322, 395, 931, 124, 944, 238, 952, 153,  33,  49, 619,
#        171, 303, 140, 532, 691, 143, 864, 794, 424, 900, 266, 868, 908,
#        179, 223, 900, 832, 647,  57, 211, 438, 457, 853], dtype=int32)

# %% [markdown]
# <font color="red">
#
# **To Do-** Choos a a few neurons (say 10) that are reasonably close to one another. Then draw the LFP's for the 10 neurons. See if you can spot some lag in time between the LFPs.

# %% [markdown]
# ## <font color="peru">Cross Correlation

# %% [markdown]
# Previously you were asked to pick neurons that were close by to each other, and then use your eyeball to see if they had similar LFP patterns. If we happen to see similar wave patterns, with some time delay between them, then we have a fantastic discovery! How do we rigorously measure time delays between channels though? This is done using [cross corrrelation](https://en.wikipedia.org/wiki/Cross-correlation)

# %% [markdown]
# lets arbitrarily select the raw data from the channels for two neurons. Note, these channels probably have no particular relationship.
#
# <font color="red"><b>To Do</b> You need to redo this code , but with selecting channels that are close by.

# %%
raw_n1 = data[ neuron_channels[0],:]
raw_n2 = data[ neuron_channels[1],:]

# %% [markdown]
# Lets plot the data from the channels

# %%
# This code could be useful later for creating plots of multiple data in one plot
raw_n1 = data[ neuron_channels[0],:]
raw_n2 = data[ neuron_channels[1],:]

plt.plot( [*range(len(raw_n1))], raw_n1 )
plt.plot( [*range(len(raw_n2))], raw_n2 )
plt.tick_params(left = False, bottom = True, labelleft = False ,  labelbottom = True) 
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# We no calculate the cross correlation. This just mean calculating the correlation many times, while shifting the data of one of the channels through time.

# %%
correlations = correlate(raw_n1, raw_n2, mode="full")

# %%
plt.plot( [*range(len(correlations))], correlations)

# %% [markdown]
# We have a function that tells us the lag time between two dataset. What this means is that it tells us at what time point the correlation is maximized.

# %%
def maxCorrelationShift(x, y):
    correlations = correlate(x, y, mode="full")
    lags = correlation_lags(x.size, y.size, mode="full")
    return lags[np.argmax(correlations)]

# %% [markdown]
# For these two particular neruons, when looking at the raw signal, there's no time shift.

# %%
maxCorrelationShift(raw_n1, raw_n2)
# Out:
# 0

# %% [markdown]
# <font color="red">
#
# **To Do-**
# Run this analysis, but with neurons selected from different points in space. Also, don't compare the raw signals, instead, compare signals from some of the bands commonly used in neuroscience.
