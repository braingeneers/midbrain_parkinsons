# %% [markdown]
# <font size=7> Data 1 - Create Raw Datasets

# %% [markdown]
# <font color="orange"> This notebook was create using the code iside the raw_data tutorial 1_processing_raw_data

# %% [markdown]
# Here we create raw datasets for further inspection

# %%
import braingeneers.data.datasets_electrophysiology as ephys
from human_hip.spike_data import read_autocurated_data,  plot_raster
from human_hip import raw_data

# %% [markdown]
# ## <font color="blue"> Look at Spike Data

# %%
sd = read_autocurated_data( "/workspaces/human_hippocampus/data/ephys/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/derived/kilosort2/Hc120523_aav9hckcr1_chip21769_121123_2_acqm.zip" )

# %%
plot_raster( sd )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
plot_raster( sd, xlim=(0, 50) )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
plot_raster( sd, xlim=(130, 180) )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
plot_raster( sd, xlim=(0, 11) )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
plot_raster( sd, xlim=(25, 39) )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
plot_raster( sd,  xlim=(139, 148) )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
plot_raster( sd,  xlim=(450, 500) )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# # 0-11 seconds

# %%
raw_data.data_get_experiments("2023-12-11-e-Hc120523_aav9hckcr1_chip21769")
# Out:
# experiment2  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_base.raw.h5.raw.h5
# experiment4  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_0.raw.h5
# experiment1  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_1.raw.h5
# experiment3  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_2.raw.h5
# experiment5  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_3.raw.h5

# %%
raw_data.data_create("2023-12-11-e-Hc120523_aav9hckcr1_chip21769", "experiment3", start_s=0, length_s=11,
                      save_path="/workspaces/human_hippocampus/data/ephys_raw/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/acid1_start0s_stop11s_fs1ms.pkl" )
# Out:
# Loading Data... might take up to 10min
# /srv/conda/envs/notebook/lib/python3.10/site-packages/braingeneers/data/datasets_electrophysiology.py:203: UserWarning: Dataset 2023-12-11-e-Hc120523_aav9hckcr1_chip21769 is not in row-major format, the parallel data reader can't be used, read speeds may be slow over a network.
#   warnings.warn(f'Dataset {batch_uuid} is not in row-major format, the parallel data reader '
# /srv/conda/envs/notebook/lib/python3.10/site-packages/braingeneers/data/datasets_electrophysiology.py:215: UserWarning: Metadata is missing the required voltage_scaling_factor attribute. Using default value of 1.0.
#   warnings.warn('Metadata is missing the required voltage_scaling_factor attribute. Using default value of 1.0.')
# Saving Data...
# Done!

# %% [markdown]
# # 25-39 seconds

# %%
raw_data.data_get_experiments("2023-12-11-e-Hc120523_aav9hckcr1_chip21769")
# Out:
# experiment2  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_base.raw.h5.raw.h5
# experiment4  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_0.raw.h5
# experiment1  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_1.raw.h5
# experiment3  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_2.raw.h5
# experiment5  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_3.raw.h5

# %%
raw_data.data_create("2023-12-11-e-Hc120523_aav9hckcr1_chip21769", "experiment3", start_s=25, length_s=14,
                      save_path="/workspaces/human_hippocampus/data/ephys_raw/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/acid1_start25s_stop39s_fs1ms.pkl" )
# Out:
# Loading Data... might take up to 10min
# Saving Data...
# Done!

# %% [markdown]
# # 139-148 seconds

# %%
raw_data.data_get_experiments("2023-12-11-e-Hc120523_aav9hckcr1_chip21769")
# Out:
# experiment2  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_base.raw.h5.raw.h5
# experiment4  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_0.raw.h5
# experiment1  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_1.raw.h5
# experiment3  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_2.raw.h5
# experiment5  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_3.raw.h5

# %%
raw_data.data_create("2023-12-11-e-Hc120523_aav9hckcr1_chip21769", "experiment3", start_s=139, length_s=9,
                      save_path="/workspaces/human_hippocampus/data/ephys_raw/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/acid1_start139s_stop148s_fs1ms.pkl" )
# Out:
# Loading Data... might take up to 10min
# Saving Data...
# Done!

# %% [markdown]
# # 481-487 seconds

# %%
raw_data.data_get_experiments("2023-12-11-e-Hc120523_aav9hckcr1_chip21769")
# Out:
# experiment2  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_base.raw.h5.raw.h5
# experiment4  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_0.raw.h5
# experiment1  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_1.raw.h5
# experiment3  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_2.raw.h5
# experiment5  -  original/data/Hc120523_aav9hckcr1_chip21769_121123_3.raw.h5

# %%
raw_data.data_create("2023-12-11-e-Hc120523_aav9hckcr1_chip21769", "experiment3", start_s=481, length_s=6,
                      save_path="/workspaces/human_hippocampus/data/ephys_raw/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/acid1_start481s_stop487s_fs1ms.pkl" )
# Out:
# Loading Data... might take up to 10min
# /srv/conda/envs/notebook/lib/python3.10/site-packages/braingeneers/data/datasets_electrophysiology.py:203: UserWarning: Dataset 2023-12-11-e-Hc120523_aav9hckcr1_chip21769 is not in row-major format, the parallel data reader can't be used, read speeds may be slow over a network.
#   warnings.warn(f'Dataset {batch_uuid} is not in row-major format, the parallel data reader '
# /srv/conda/envs/notebook/lib/python3.10/site-packages/braingeneers/data/datasets_electrophysiology.py:215: UserWarning: Metadata is missing the required voltage_scaling_factor attribute. Using default value of 1.0.
#   warnings.warn('Metadata is missing the required voltage_scaling_factor attribute. Using default value of 1.0.')
# Saving Data...
# Done!

# %% [markdown]
# # Raw Recordings

# %%
raw_data.data_create("2023-12-11-e-Hc120523_aav9hckcr1_chip21769", "experiment3", start_s=320, length_s=8,
                      save_path="/workspaces/human_hippocampus/data/ephys_raw/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/acid1_start320s_stop328s_fs1ms.pkl" )
# Out:
# Loading Data... might take up to 10min
# /srv/conda/envs/notebook/lib/python3.10/site-packages/braingeneers/data/datasets_electrophysiology.py:203: UserWarning: Dataset 2023-12-11-e-Hc120523_aav9hckcr1_chip21769 is not in row-major format, the parallel data reader can't be used, read speeds may be slow over a network.
#   warnings.warn(f'Dataset {batch_uuid} is not in row-major format, the parallel data reader '
# /srv/conda/envs/notebook/lib/python3.10/site-packages/braingeneers/data/datasets_electrophysiology.py:215: UserWarning: Metadata is missing the required voltage_scaling_factor attribute. Using default value of 1.0.
#   warnings.warn('Metadata is missing the required voltage_scaling_factor attribute. Using default value of 1.0.')
# Saving Data...
# Done!

# %%
raw_data.data_create("2023-12-11-e-Hc120523_aav9hckcr1_chip21769", "experiment3", start_s=168, length_s=6,
                      save_path="/workspaces/human_hippocampus/data/ephys_raw/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/acid1_start168s_stop174s_fs1ms.pkl" )
# Out:
# Loading Data... might take up to 10min
# Saving Data...
# Done!

# %%
raw_data.data_create("2023-12-11-e-Hc120523_aav9hckcr1_chip21769", "experiment3", start_s=258, length_s=5,
                      save_path="/workspaces/human_hippocampus/data/ephys_raw/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/acid1_start258s_stop263s_fs1ms.pkl" )
# Out:
# Loading Data... might take up to 10min
# Saving Data...
# Done!

# %% [markdown]
# # Nonseizure recordings

# %%
nonseizure = [ [50,60] ,[100,113], [200, 212], [270,275], [392, 400],  [400,406], [450,455] ]

# %%
for start,end in nonseizure:
    raw_data.data_create("2023-12-11-e-Hc120523_aav9hckcr1_chip21769", "experiment3",  start_s=start, length_s=end-start,
                          save_path="/workspaces/human_hippocampus/data/ephys_raw/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/nonseizure/acid1_start{}s_stop{}s_fs1ms.pkl".format(start,end) )
# Out:
# Loading Data... might take up to 10min
# Saving Data...
# Done!
# Loading Data... might take up to 10min
# Saving Data...
# Done!
# Loading Data... might take up to 10min
# Saving Data...
# Done!
# Loading Data... might take up to 10min
# Saving Data...
# Done!
# Loading Data... might take up to 10min
# Saving Data...
# Done!
# Loading Data... might take up to 10min
# Saving Data...
# Done!

# %%
raw_data.data_create("2023-12-11-e-Hc120523_aav9hckcr1_chip21769", "experiment3",  start_s=270, length_s=5,
                        save_path="/workspaces/human_hippocampus/data/ephys_raw/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/nonseizure/acid1_start270s_stop275s_fs1ms.pkl" )
# Out:
# Loading Data... might take up to 10min
# Saving Data...
# Done!
