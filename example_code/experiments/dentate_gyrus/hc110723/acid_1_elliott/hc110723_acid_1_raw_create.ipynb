# %% [markdown]
# <font size=7> Data 1 - Create Raw Datasets

# %% [markdown]
# <font color="orange"> This notebook was create using the code iside the raw_data tutorial 1_processing_raw_data

# %% [markdown]
# Here we create raw datasets for further inspection

# %%
import braingeneers.data.datasets_electrophysiology as ephys
from human_hip.spike_data import read_phy_files, read_autocurated_data,  plot_raster
from human_hip import raw_data
import pickle

# %% [markdown]
# ## <font color="blue"> Look at Spike Data

# %%
sd = read_phy_files("/workspaces/human_hippocampus/data/ephys/2023-11-13-e-Hc110723_hckcr1_21841/elliott/hc110723_2.zip")
# with open("sd_curated.pkl", "rb") as f:
#     sd = pickle.load(f)

# %%
plot_raster( sd )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
plot_raster
# Out:
# <function human_hip.spike_data.plot_raster.plot_raster(sd, title='', axs=None, xlim=None, smoothness=20, size=(16, 6))>

# %%
plot_raster( sd, xlim=(33, 43) )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Neural Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# # 33-43 seconds

# %%
raw_data.data_get_experiments("2023-11-13-e-Hc110723_hckcr1_21841")
# Out:
# experiment1  -  original/data/Hc110723_hckcr1_21841_111323_base.raw.h5
# experiment9  -  original/data/Hc110723_hckcr1_21841_111323_0.raw.h5
# experiment2  -  original/data/Hc110723_hckcr1_21841_111323_1.raw.h5
# experiment7  -  original/data/Hc110723_hckcr1_21841_111323_2.raw.h5
# experiment4  -  original/data/Hc110723_hckcr1_21841_111323_3.raw.h5
# experiment6  -  original/data/Hc110723_hckcr1_21841_111323_4.raw.h5
# experiment5  -  original/data/Hc110723_hckcr1_21841_111323_5.raw.h5
# experiment3  -  original/data/Hc110723_hckcr1_21841_111323_csf.raw.h5.raw.h5
# experiment8  -  original/data/Hc110723_hckcr1_21841_111323_6.raw.h5

# %%
raw_data.data_create("2023-11-13-e-Hc110723_hckcr1_21841", "experiment7", start_s=33, length_s=10,
                      save_path="/workspaces/human_hippocampus/data/ephys_raw/2023-11-13-e-Hc110723_hckcr1_21841/acid1_start33s_stop43s_fs1ms.pkl" )
# Out:
# Loading Data... might take up to 10min
# /srv/conda/envs/notebook/lib/python3.10/site-packages/braingeneers/data/datasets_electrophysiology.py:203: UserWarning: Dataset 2023-11-13-e-Hc110723_hckcr1_21841 is not in row-major format, the parallel data reader can't be used, read speeds may be slow over a network.
#   warnings.warn(f'Dataset {batch_uuid} is not in row-major format, the parallel data reader '
# /srv/conda/envs/notebook/lib/python3.10/site-packages/braingeneers/data/datasets_electrophysiology.py:215: UserWarning: Metadata is missing the required voltage_scaling_factor attribute. Using default value of 1.0.
#   warnings.warn('Metadata is missing the required voltage_scaling_factor attribute. Using default value of 1.0.')
# Saving Data...
# Done!

# %% [markdown]
# # 145-155 seconds

# %%
raw_data.data_create("2023-11-13-e-Hc110723_hckcr1_21841", "experiment7", start_s=145, length_s=10,
                      save_path="/workspaces/human_hippocampus/data/ephys_raw/2023-11-13-e-Hc110723_hckcr1_21841/acid1_start145s_stop155s_fs1ms.pkl" )
# Out:
# Loading Data... might take up to 10min
# /srv/conda/envs/notebook/lib/python3.10/site-packages/braingeneers/data/datasets_electrophysiology.py:203: UserWarning: Dataset 2023-11-13-e-Hc110723_hckcr1_21841 is not in row-major format, the parallel data reader can't be used, read speeds may be slow over a network.
#   warnings.warn(f'Dataset {batch_uuid} is not in row-major format, the parallel data reader '
# /srv/conda/envs/notebook/lib/python3.10/site-packages/braingeneers/data/datasets_electrophysiology.py:215: UserWarning: Metadata is missing the required voltage_scaling_factor attribute. Using default value of 1.0.
#   warnings.warn('Metadata is missing the required voltage_scaling_factor attribute. Using default value of 1.0.')
# Saving Data...
# Done!

# %% [markdown]
# # 110-120 seconds

# %%
raw_data.data_create("2023-11-13-e-Hc110723_hckcr1_21841", "experiment7", start_s=110, length_s=10,
                      save_path="/workspaces/human_hippocampus/data/ephys_raw/2023-11-13-e-Hc110723_hckcr1_21841/acid1_start110s_stop120s_fs1ms.pkl" )
# Out:
# Loading Data... might take up to 10min
# Saving Data...
# Done!
