# %% [markdown]
# <font size=7> 2023-05-10-e-hc52_18790 - Bicuculline Analysis

# %% [markdown]
# Inspect Bicuculline Data

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
from braingeneers.analysis.analysis import SpikeData
from human_hip.basics import read_phy_files, raster_plot, raster_fancy_plot

# %% [markdown]
# # Rec 1

# %%
sd = read_phy_files("/workspaces/human_hippocampus/data/ephys/2023-05-10-e-hc52_18790/derived/kilosort2/hc52_chip18790_rec51023_1_curated.zip")

# %%
fig, ax = plt.subplots(figsize=(20, 8))
raster_plot(sd, ax)
plt.show()

# %%
raster_fancy_plot(sd, xsize=25, ysize=5, start_time=0, stop_time=70)

# %%
raster_fancy_plot(sd, xsize=25, ysize=5, start_time=40, stop_time=60)

# %%
raster_fancy_plot(sd, xsize=25, ysize=5, start_time=50, stop_time=60)

# %%
raster_fancy_plot(sd, xsize=25, ysize=10, start_time=56, stop_time=60)

# %% [markdown]
# # Rec 2

# %%
sd2 = read_phy_files("/workspaces/human_hippocampus/data/ephys/2023-05-10-e-hc52_18790/derived/kilosort2/hc52_chip18790_rec51023_2_curated.zip")

# %%
fig, ax = plt.subplots(figsize=(20, 8))
raster_plot(sd, ax)
plt.show()

# %%
raster_fancy_plot(sd, xsize=25, ysize=5, start_time=50, stop_time=60)

# %% [markdown]
# # Create Raw Data
