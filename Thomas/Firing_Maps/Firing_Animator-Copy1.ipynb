# %%
import os
import re
import glob
import random
import numpy as np
import scipy
import scipy.io as sio
import scipy.ndimage as ndimage
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as patches
from matplotlib.lines import Line2D
from PIL import Image
from ipywidgets import interact, interactive, fixed, interact_manual
import braingeneers
import braingeneers.data.datasets_electrophysiology as ephys
from braingeneers.analysis.analysis import SpikeData, read_phy_files

# %%
def analyze_data(start, stop, dataset_number):
    dataset_path = f"/home/jovyan/work/Human_Hippocampus/data/ephys/2023-04-02-hc328_rec/derived/kilosort2/2023_04_02_hc328_{dataset_number}_curated.zip"
    
    # Map dataset_number to the corresponding light_data file
    light_data_files = {
        0: "20230402T140926-2023_04_02_hc328_0_opto_stim_log.csv",
        1: "20230402T141431-2023_04_02_hc328_1_opto_stim_log.csv",
        2: "20230402T142358-2023_04_02_hc328_2_opto_stim_log.csv",
        3: "20230402T142533-2023_04_02_hc328_3_opto_stim_log.csv",
        4: "20230402T142658-2023_04_02_hc328_4_opto_stim_log.csv",
        5: "20230402T142907-2023_04_02_hc328_5_opto_stim_log.csv",
        6: "20230402T144122-2023_04_02_hc328_6_opto_stim_log.csv",
        7: "20230402T145210-2023_04_02_hc328_7_opto_stim_log.csv"
    }

    # Check if the dataset_number is valid
    if dataset_number not in light_data_files:
        raise ValueError("Invalid dataset_number")

    # Get the corresponding light_data file
    light_data_file = light_data_files[dataset_number]

    # Construct the light_data_path
    light_data_path = f"/home/jovyan/work/Human_Hippocampus/data/opto/hc328_20230402T14/{light_data_file}"
    
    # Read the CSV file into a DataFrame
    light_data = pd.read_csv(light_data_path)

    
    # Read the CSV file into a DataFrame
    light_data = pd.read_csv(light_data_path)

    # Rename the "time (sec)" column
    light_data = light_data.rename(columns={"time (sec)": "time change (sec)"})
    
    # Calculate the time change values by subtracting the first value from each subsequent value
    light_data["time change (sec)"] = light_data["time change (sec)"] - light_data.at[0, "time change (sec)"]

    # Modify the values in the "time change (sec)" column based on the dataset number
    if dataset_number == 5:
        light_data["time change (sec)"] = light_data["time change (sec)"] + 10
    elif dataset_number == 6:
        light_data["time change (sec)"] = light_data["time change (sec)"] + 1

    # Rename the "on_duration (frames)" column
    light_data = light_data.rename(columns={"on_duration (frames)": "on_duration (seconds)"})

    # Divide the values in the "on_duration (seconds)" column by 20000
    light_data["on_duration (seconds)"] = light_data["on_duration (seconds)"] / 20000

    # Rename the "off_duration (frames)" column
    light_data = light_data.rename(columns={"off_duration (frames)": "off_duration (seconds)"})

    # Divide the values in the "off_duration (seconds)" column by 20000
    light_data["off_duration (seconds)"] = light_data["off_duration (seconds)"] / 20000

    # Create a list "light_times" from the values in the first column
    light_times = light_data.iloc[:, 0].tolist()
    
    sd = read_phy_files(dataset_path)
    sd_start = sd.subtime(start*1000, stop*1000)

    
    # Check if start is equal to or at most 10 above any number from light_data
    if any(0 <= start - time <= 10 for time in light_times):
        background_color = (0.6, 0.8, 0.4, 0.5)  # Lighter yellowgreen with an opacity of 0.5
    else:
        background_color = None

    def calculate_mean_firing_rates(spike_data):
        mean_firing_rates = []
        for neuron_spikes in spike_data.train:
            num_spikes = len(neuron_spikes)
            time_duration = spike_data.length / 1000  # Assuming spike times are in milliseconds
            firing_rate = num_spikes / time_duration
            mean_firing_rates.append(firing_rate)

        return np.array(mean_firing_rates)
    
    firing_rates = calculate_mean_firing_rates(sd_start)
    
    def firing_plotter(sd):
        neuron_x = []
        neuron_y = []

        for neuron in sd.neuron_data[0].values():
            neuron_x.append(neuron['position'][0])
            neuron_y.append(neuron['position'][1])

        plt.figure(figsize=(8, 6))
        # Increase the 's' parameter to make the scatter points larger
        # Adjust the 'alpha' parameter to make the scatter points less opaque
        plt.scatter(neuron_x, neuron_y, s=firing_rates*10+firing_rates**2.3, alpha=0.3,c ='r')
        
        if background_color:
            plt.gca().set_facecolor(background_color)
        
        plt.xlabel('um')
        plt.ylabel('um')
        plt.title(f"{start} sec.png")  # Adding the title

        # Set fixed limits for x and y axes
        plt.xlim(600, 1500)
        plt.ylim(0, 2200)
        
        plt.savefig(f"/home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_{dataset_number}/{start}_sec.png")
        plt.close()
        
    firing_plotter(sd_start)

    return f"/home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_{dataset_number}/{start}_sec.png"

# def create_animated_gif(dataset_number):
#     # TODO: Make the directory a parameter you can set in the function
    
#     # Define the directory path
#     directory = '/home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/'

#     # Create a subdirectory to save the figures
#     figures_directory = os.path.join(directory, f"dataset_{dataset_number}")
#     if not os.path.exists(figures_directory):
#         os.makedirs(figures_directory)
#     dataset_path = f"/home/jovyan/work/Human_Hippocampus/data/ephys/2023-04-02-hc328_rec/derived/kilosort2/2023_04_02_hc328_{dataset_number}_curated.zip"
    
#     sd = read_phy_files(dataset_path)
#     length = int(sd.length/1000) 
    
#     # Iterate over each second of the data
#     for second in range(length):
#         start = second
#         stop = second + 1

#         # Call analyze_data function
#         image_path = analyze_data(start, stop, dataset_number)
#         print(f"Generated image: {image_path}")

#     # Directory path where the PNG files are located
#     directory = figures_directory

#     # Create a list of file names in the directory
#     file_list = sorted([filename for filename in os.listdir(directory) if filename.endswith('.png')], key=lambda x: int(re.search(r'\d+', x).group()))

#     # Create a list to store the image frames
#     frames = []

#     # Iterate over each file and add it to the frames list
#     for filename in file_list:
#         # Create the full file path
#         file_path = os.path.join(directory, filename)

#         # Open the image file and append it to the frames list
#         image = Image.open(file_path)
#         frames.append(image)

#     # Save the frames as an animated GIF
#     save_path = "/home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/" + f"Dataset_{dataset_number}.gif"
#     frames[0].save(save_path, format='GIF', append_images=frames[1:], save_all=True, duration=400, loop=0)
def create_animated_gif(dataset_number):
    # TODO: Make the directory a parameter you can set in the function
    
    # Define the directory path
    directory = '/home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/'

    # Create a subdirectory to save the figures
    figures_directory = os.path.join(directory, f"dataset_{dataset_number}")
    if not os.path.exists(figures_directory):
        os.makedirs(figures_directory)
    dataset_path = f"/home/jovyan/work/Human_Hippocampus/data/ephys/2023-04-02-hc328_rec/derived/kilosort2/2023_04_02_hc328_{dataset_number}_curated.zip"
    
    sd = read_phy_files(dataset_path)
    length = int(sd.length/1000) 
    
    # Iterate over each half-second of the data
    for half_second in range(length * 2):
        start = half_second / 2
        stop = start + 0.5

        # Call analyze_data function
        image_path = analyze_data(start, stop, dataset_number)
        print(f"Generated image: {image_path}")

    # Directory path where the PNG files are located
    directory = figures_directory

    # Create a list of file names in the directory
#     file_list = sorted([filename for filename in os.listdir(directory) if filename.endswith('.png')], key=lambda x: int(re.search(r'\d+', x).group()))
    file_list = sorted([filename for filename in os.listdir(directory) if filename.endswith('.png')], key=lambda x: int(x.split("_")[0]))


    # Create a list to store the image frames
    frames = []

    # Iterate over each file and add it to the frames list
    for filename in file_list:
        # Create the full file path
        file_path = os.path.join(directory, filename)

        # Open the image file and append it to the frames list
        image = Image.open(file_path)
        frames.append(image)

    # Save the frames as an animated GIF
    save_path = "/home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/" + f"Dataset_{dataset_number}.gif"
    frames[0].save(save_path, format='GIF', append_images=frames[1:], save_all=True, duration=250, loop=0)

# %%
# Example usage
create_animated_gif(dataset_number=6)
# Out:
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/0.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/0.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/1.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/1.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/2.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/2.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/3.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/3.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/4.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/4.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/5.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/5.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/6.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/6.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/7.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/7.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/8.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/8.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/9.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/9.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/10.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/10.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/11.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/11.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/12.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/12.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/13.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/13.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/14.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/14.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/15.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/15.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/16.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/16.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/17.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/17.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/18.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/18.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/19.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/19.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/20.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/20.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/21.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/21.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/22.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/22.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/23.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/23.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/24.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/24.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/25.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/25.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/26.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/26.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/27.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/27.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/28.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/28.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/29.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/29.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/30.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/30.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/31.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/31.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/32.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/32.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/33.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/33.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/34.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/34.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/35.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/35.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/36.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/36.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/37.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/37.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/38.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/38.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/39.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/39.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/40.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/40.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/41.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/41.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/42.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/42.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/43.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/43.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/44.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/44.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/45.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/45.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/46.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/46.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/47.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/47.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/48.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/48.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/49.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/49.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/50.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/50.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/51.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/51.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/52.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/52.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/53.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/53.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/54.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/54.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/55.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/55.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/56.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/56.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/57.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/57.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/58.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/58.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/59.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/59.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/60.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/60.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/61.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/61.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/62.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/62.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/63.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/63.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/64.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/64.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/65.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/65.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/66.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/66.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/67.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/67.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/68.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/68.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/69.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/69.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/70.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/70.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/71.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/71.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/72.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/72.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/73.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/73.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/74.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/74.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/75.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/75.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/76.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/76.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/77.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/77.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/78.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/78.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/79.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/79.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/80.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/80.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/81.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/81.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/82.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/82.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/83.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/83.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/84.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/84.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/85.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/85.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/86.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/86.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/87.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/87.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/88.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/88.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/89.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/89.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/90.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/90.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/91.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/91.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/92.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/92.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/93.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/93.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/94.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/94.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/95.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/95.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/96.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/96.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/97.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/97.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/98.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/98.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/99.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/99.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/100.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/100.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/101.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/101.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/102.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/102.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/103.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/103.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/104.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/104.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/105.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/105.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/106.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/106.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/107.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/107.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/108.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/108.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/109.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/109.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/110.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/110.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/111.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/111.5_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/112.0_sec.png
# Generated image: /home/jovyan/work/Human_Hippocampus/saved_plots/firing_animations/dataset_6/112.5_sec.png
