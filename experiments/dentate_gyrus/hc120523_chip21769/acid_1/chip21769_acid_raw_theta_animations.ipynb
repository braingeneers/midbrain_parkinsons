# %% [markdown]
# <font size=7>Animate Seizure Event

# %% [markdown]
# # Setup

# %% [markdown]
# Here we check to see if there are any interesting patterns during the seizure event.

# %%
import pickle
from human_hip import spike_data
from matplotlib import pyplot as plt
from human_hip.raw_data import get_brain_waves
from human_hip.animate import animate_waves
from human_hip.spike_data import read_autocurated_data, plot_raster

# %%
sd = spike_data.read_autocurated_data( "/workspaces/human_hippocampus/data/ephys/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/derived/kilosort2/Hc120523_aav9hckcr1_chip21769_121123_2_acqm.zip" )

# %%
plot_raster( sd )
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %% [markdown]
# # 0-11 seconds

# %%
plot_raster( sd , xlim=(0, 11))
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
with open("/workspaces/human_hippocampus/data/ephys_raw/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/acid1_start0s_stop11s_fs1ms.pkl", 'rb') as filename:
    data_raw = pickle.load(filename)
print(data_raw.keys())
print(data_raw["data"].shape)
# Out:
# dict_keys(['data', 'xy', 'frame_rate', 'uuid', 'file'])
# (894, 11000)

# %%
animate_waves(data_raw, wave_type="theta", movie_range_ms=range(0,3000,5), filename='media/chip21769_acid1_theta_start0s_range_0_3000_5.mp4' )
# Out:
# Making animation of 1.0 minutes
# Saved animation to media/chip21769_acid1_theta_start0s_range_0_3000_5.mp4

# %% [markdown]
# # 25-39 seconds

# %%
plot_raster( sd , xlim=(25, 39))
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
with open("/workspaces/human_hippocampus/data/ephys_raw/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/acid1_start25s_stop39s_fs1ms.pkl", 'rb') as filename:
    data_raw = pickle.load(filename)
print(data_raw.keys())
print(data_raw["data"].shape)
# Out:
# dict_keys(['data', 'xy', 'frame_rate', 'uuid', 'file'])
# (894, 14000)

# %%
animate_waves(data_raw, wave_type="theta", movie_range_ms=range(9000,12000,5), filename='media/chip21769_acid1_theta_start0s_range_9000_12000_5.mp4' )
# Out:
# Making animation of 1.0 minutes
# Saved animation to media/chip21769_acid1_theta_start0s_range_9000_12000_5.mp4

# %%
animate_waves(data_raw, wave_type="theta", movie_range_ms=range(10000,14000,5), filename='media/chip21769_acid1_theta_start25s_range_10000_14000_5.mp4' )
# Out:
# Making animation of 1.333 minutes
# Saved animation to media/chip21769_acid1_theta_start25s_range_10000_14000_5.mp4

# %% [markdown]
# # 139-148 seconds

# %%
plot_raster( sd , xlim=(139, 148))
# Out:
# (<Axes: xlabel='Time (s)', ylabel='Unit'>,
#  <Axes: xlabel='Time (ms)', ylabel='Population Firing Rate (Hz)'>)

# %%
with open("/workspaces/human_hippocampus/data/ephys_raw/2023-12-11-e-Hc120523_aav9hckcr1_chip21769/acid1_start139s_stop148s_fs1ms.pkl", 'rb') as filename:
    data_raw = pickle.load(filename)
print(data_raw.keys())
print(data_raw["data"].shape)
# Out:
# dict_keys(['data', 'xy', 'frame_rate', 'uuid', 'file'])
# (894, 9000)

# %%
animate_waves(data_raw, wave_type="theta", movie_range_ms=range(1000,4000,5), filename='media/chip21769_acid1_theta_start139s_range_1000_4000_5.mp4' )
# Out:
# Making animation of 1.0 minutes
# Saved animation to media/chip21769_acid1_theta_start139s_range_1000_4000_5.mp4
