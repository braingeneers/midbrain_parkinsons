# %% [markdown]
# <font size=7> basic analysis of CA1

# %% [markdown]
# # Set Up Notebook

# %% [markdown]
# Load functions for  basic analysis
#
# <font color="orange"> Late replace this with `import basics`

# %%
# %run /workspaces/human_hippocampus/src/human_hip/basics/basics_source_code.ipynb
# Out:
# 	Loading analysis source code...
# /srv/conda/envs/notebook/lib/python3.10/site-packages/nbformat/__init__.py:93: MissingIDFieldWarning: Code cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# 	Done!

# %% [markdown]
# load data

# %%
import pickle
file = open('/workspaces/human_hippocampus/data/ephys/StitchedDataUpdated.pkl', 'rb')
sd = pickle.load(file)
file.close()

# %% [markdown]
# # Basic Graphs

# %% [markdown]
# plot firing rate in layout view

# %%
firing_rates = calculate_mean_firing_rates(sd)
neuron_x = []
neuron_y = []

for neuron in sd.neuron_data[0].values():
    neuron_x.append(neuron["position"][0])
    neuron_y.append(neuron["position"][1])
# Out:
# /tmp/ipykernel_3378/3585257705.py:5: DeprecationWarning: Call to deprecated function (or staticmethod) neuron_data. (Use NeuronAttributes instead of neuron_data, with the function load_spike_data())
#   for neuron in sd.neuron_data[0].values():

# %%
plt.scatter(neuron_x, neuron_y, s=firing_rates*100, c="red", alpha=0.3)
#plots[1,0].scatter(neuron_x, neuron_y, s=(2**firing_rates)*10, c="red", alpha=0.3)
#plt.set_title("Neuron Firing Rate Across MEA")
#plt.set_xlabel("um")
#plt.set_ylabel("um")
